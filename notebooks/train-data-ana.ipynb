# %%
import pandas as pd

df = pd.read_csv('training_data.csv')
df.info()
df.head()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18191 entries, 0 to 18190
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   hour                   18191 non-null  int64
#  1   is_night               18191 non-null  int64
#  2   is_weekend             18191 non-null  int64
#  3   country_change         18191 non-null  int64
#  4   device_change          18191 non-null  int64
#  5   failed_before_success  18191 non-null  int64
#  6   rapid_login_rate       18191 non-null  int64
#  7   login_frequency_today  18191 non-null  int64
#  8   label                  18191 non-null  int64
# dtypes: int64(9)
# memory usage: 1.2 MB
#                hour      is_night    is_weekend  country_change  \
# count  18191.000000  18191.000000  18191.000000    18191.000000
# mean      11.887197      0.200594      0.272992        0.009730
# std        6.064272      0.400456      0.445509        0.098163
# ...
